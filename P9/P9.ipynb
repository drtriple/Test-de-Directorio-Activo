# %% [markdown]
# **##JUAN JOSÉ BEDOYA CHAVARRÍA**
#
# # Situación:
#
# Proponga un script en powershell que permita inspeccionar todos los controladores de un dominio en búsqueda de las tareas programadas que se ejecutan con el usuario "virus01":

# %% [markdown]
# SIN REALIZAR
